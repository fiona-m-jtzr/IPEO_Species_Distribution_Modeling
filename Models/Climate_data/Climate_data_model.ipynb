# %% [markdown]
# # Species distribution modeling with climate data

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Install dependencies

# %%
# !pip install -U -q torch==2.5.0 torchvision matplotlib tqdm gdown
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 720.0 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 142.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 107.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 826.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.9 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /packages/ff/ff/847841bacfbefc97a00036e0fce5a0f086b640756dc38caea5e1bb002655/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 123.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 149.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 119.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 157.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.9.0+cu126 requires torch==2.9.0, but you have torch 2.5.0 which is incompatible.

# %%
# !pip install scikit-multilearn
# !pip install folium
# Out:
# Collecting scikit-multilearn
#   Downloading scikit_multilearn-0.2.0-py3-none-any.whl.metadata (6.0 kB)
# Downloading scikit_multilearn-0.2.0-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.4/89.4 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: scikit-multilearn
# Successfully installed scikit-multilearn-0.2.0
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.11.12)

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score, fbeta_score, label_ranking_loss, roc_auc_score, average_precision_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 1.2 Check if cuda available

# %%
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ## 2. Data loading

# %% [markdown]
# ### 2.1 Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2.1 Downloading data

# %%
base_path = "/content/drive/MyDrive/IPEO/Project/"

os.chdir(base_path)
os.getcwd()
# Out:
# '/content/drive/MyDrive/IPEO/Project'

# %%
env_train = pd.read_csv("data/env_variables_training.csv")
env_test  = pd.read_csv("data/env_variables_test.csv")

species_train = np.load("data/species_data_training.npy")
species_test  = np.load("data/species_data_test.npy")

print("Training shapes:")
print("Env:", env_train.shape)
print("Labels:", species_train.shape)
# Out:
# Training shapes:
# Env: (5000, 22)
# Labels: (5000, 342)

# %% [markdown]
# ### 2.2 Reshaping and removing columns

# %%
# Extract coordinates
train_lons = env_train.iloc[:, 1]
train_lats = env_train.iloc[:, 2]

test_lons = env_test.iloc[:, 1]
test_lats = env_test.iloc[:, 2]

env_train = env_train.values.astype(np.float32)
env_test  = env_test.values.astype(np.float32)

env_train = env_train[:, 3:]
env_test  = env_test[:, 3:]

species_train = species_train.astype(np.float32)
species_test  = species_test.astype(np.float32)

print("Env train shape after removing first 3 columns:", env_train.shape)
print("Env test shape after removing first 3 columns:", env_test.shape)
# Out:
# Env train shape after removing first 3 columns: (5000, 19)
# Env test shape after removing first 3 columns: (1000, 19)

# %% [markdown]
# ### 2.3 Defining dataset class

# %%
class GeoPlantDataset(Dataset):
    def __init__(self, tabular, labels, split='train', val_split=0.2, random_state=42):
        """
        Args:
            tabular: numpy array of climate data
            labels: numpy array of species labels
            split: 'train', 'val', 'test', or None
            val_split: fraction of training data to use for validation (ignored if split is None)
            random_state: random seed for reproducibility
        """
        self.split = split

        if split == 'test' or split is None:
            self.tabular = tabular
            self.labels = labels

        else:
            indices = np.arange(len(labels))

            if val_split <= 0:
                self.tabular = tabular
                self.labels = labels
            else:
                train_idx, val_idx = train_test_split(
                    indices,
                    test_size=val_split,
                    random_state=random_state
                )

                if split == 'train':
                    self.tabular = tabular[train_idx]
                    self.labels = labels[train_idx]
                elif split == 'val':
                    self.tabular = tabular[val_idx]
                    self.labels = labels[val_idx]

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        tab = torch.from_numpy(self.tabular[idx]).float()
        y   = torch.from_numpy(self.labels[idx]).float()
        return tab, y

# %% [markdown]
# ### 2.4 Creating dataset

# %%
# Create datasets with train/val split
train_dataset = GeoPlantDataset(
    tabular=env_train,
    labels=species_train,
    split='train',
    val_split=0.2
)

val_dataset = GeoPlantDataset(
    tabular=env_train,
    labels=species_train,
    split='val',
    val_split=0.2
)

test_dataset = GeoPlantDataset(
    tabular=env_test,
    labels=species_test,
    split='test'
)


# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)

print(f"Train samples: {len(train_dataset)}")
print(f"Val samples: {len(val_dataset)}")
print(f"Test samples: {len(test_dataset)}")
# Out:
# Train samples: 4000
# Val samples: 1000
# Test samples: 1000

# %% [markdown]
# ### 2.5 Checking dimensions

# %%
tab, y = train_dataset[0]

print("Tabular:", tab.shape)
print("Label:", y.shape)
# Out:
# Tabular: torch.Size([19])
# Label: torch.Size([342])

# %% [markdown]
# ## 3. Satellite imagery species distribution model

# %%
class TabularEncoder(nn.Module):
    def __init__(self, in_features=19, out_features=342):
        super().__init__()
        self.net = nn.Sequential(
          nn.Linear(in_features, 64),
          nn.BatchNorm1d(64),
          nn.ReLU(),
          nn.Dropout(0.1),

          nn.Linear(64, 128),
          nn.BatchNorm1d(128),
          nn.ReLU(),
          nn.Dropout(0.2),

          nn.Linear(128, 256),
          nn.BatchNorm1d(256),
          nn.ReLU(),
          nn.Dropout(0.3),

          nn.Linear(256, 512),
          nn.BatchNorm1d(512),
          nn.ReLU(),

          nn.Linear(512, out_features)
        )

    def forward(self, x):
        return self.net(x)

model = TabularEncoder(in_features=19, out_features=342)
print("Climate model with parameters:", sum(p.numel() for p in model.parameters()))
# Out:
# Climate model with parameters: 351574

# %% [markdown]
# ## 4. Training the model

# %% [markdown]
# ### 4.1 Training one epoch

# %%
def train_epoch(model, loader, optimizer, criterion, device='cpu'):
    model.train()
    running_loss = 0.0
    samples_processed = 0

    for tab, y in loader:
        tab = tab.to(device).float()
        y = y.to(device).float()

        optimizer.zero_grad()

        # Forward pass
        logits = model(tab)
        loss = criterion(logits, y)

        # Backward pass
        loss.backward()

        # Gradient Clipping (Focal loss)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()

        # Accurate accumulation
        batch_size = tab.size(0)
        running_loss += loss.item() * batch_size
        samples_processed += batch_size

    return running_loss / samples_processed

# %% [markdown]
# ### 4.2 Evaluation of the model

# %%
def evaluate(model, loader, criterion, device='cpu'):
    model.eval()
    all_preds = []
    all_labels = []
    running_loss = 0.0
    samples_processed = 0

    with torch.no_grad():
        for tab, y in loader:
            tab = tab.to(device).float()
            y = y.to(device).float()

            logits = model(tab)
            loss = criterion(logits, y)

            running_loss += loss.item() * tab.size(0)
            samples_processed += tab.size(0)

            # Probabilities for ranking metrics
            probs = torch.sigmoid(logits)
            all_preds.append(probs.cpu())
            all_labels.append(y.cpu())

    all_preds = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()

    # Robust AUC Calculation
    try:
        macro_auc = roc_auc_score(all_labels, all_preds, average='macro')
    except ValueError:
        # Fallback if some classes have no positives in this fold
        macro_auc = 0.0
        print("Warning: Some classes had no positive samples in this fold.")

    # Average Precision
    macro_avg_prec = average_precision_score(all_labels, all_preds, average='macro')

    avg_loss = running_loss / samples_processed

    return macro_auc, macro_avg_prec, avg_loss

# %% [markdown]
# ### 4.3 Calculate species weights (for param alpha in focal loss function)

# %%
counts = species_train.sum(axis=0)
total_samples = len(species_train)

weights = total_samples / (counts + 1e-5)

weights = weights / weights.mean()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
species_weights = torch.tensor(weights, dtype=torch.float).to(device)

# %% [markdown]
# ### 4.4 Focal loss function

# %%
class MultiLabelFocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=0.25):
        super(MultiLabelFocalLoss, self).__init__()
        self.gamma = gamma

        # Parameter alpha can be a float or a tensor of shape (num_classes,)
        self.alpha = alpha

    def forward(self, logits, targets):
        bce_loss = F.binary_cross_entropy_with_logits(logits, targets, reduction='none')

        # Compute p_t (probability of ground truth)
        probs = torch.sigmoid(logits)
        p_t = probs * targets + (1 - probs) * (1 - targets)

        # Modulating factor (Focal component)
        focal_weight = (1 - p_t) ** self.gamma

        # Corrected Alpha Balancing for Multi-Label
        if isinstance(self.alpha, torch.Tensor):
            alpha_pos = self.alpha
            alpha_neg = 1 - 0.25 # Keep negative weight constant and small
            alpha_weight = targets * alpha_pos + (1 - targets) * alpha_neg
        else:
            # Standard scalar behavior
            alpha_weight = targets * self.alpha + (1 - targets) * (1 - self.alpha)

        loss = alpha_weight * focal_weight * bce_loss

        return loss.mean()

# %% [markdown]
# ### 4.5 K-fold cross validation

# %%
import numpy as np
from torch.utils.data import DataLoader, Subset
from skmultilearn.model_selection import IterativeStratification

device = "cuda" if torch.cuda.is_available() else "cpu"

# Define the K-Fold splitter
k_folds = 5
stratifier = IterativeStratification(n_splits=k_folds, order=1)

# Initialize indices
indices = np.arange(len(env_train))

# Store results for Out-of-fold (OOF) analysis
oof_probs = np.zeros(species_train.shape)

for fold, (train_idx, val_idx) in enumerate(stratifier.split(env_train, species_train)):
    print(f"\n--- Starting Fold {fold+1}/{k_folds} ---")

    # Initial DataLoader setup using split=None
    full_train_data = GeoPlantDataset(tabular=env_train, labels=species_train, split=None)
    train_loader = DataLoader(Subset(full_train_data, train_idx), batch_size=32, shuffle=True)
    val_loader = DataLoader(Subset(full_train_data, val_idx), batch_size=32, shuffle=False)

    # 3. Initialize fresh model for every fold
    model = TabularEncoder().to(device)
    criterion = MultiLabelFocalLoss(gamma=2.0, alpha=0.25)
    optimizer = torch.optim.AdamW(model.parameters())
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5)

    EPOCHS = 50
    best_val_avg_prec = 0
    best_model_state = None

    train_loss_list = []
    val_loss_list = []
    macro_auc_list = []
    macro_avg_prec_list = []

    for epoch in range(EPOCHS):
        train_loss = train_epoch(model, train_loader, optimizer, criterion, device=device)
        val_auc, val_avg_prec, val_loss = evaluate(model, val_loader, criterion, device=device)

        train_loss_list.append(train_loss)
        val_loss_list.append(val_loss)
        macro_auc_list.append(val_auc)
        macro_avg_prec_list.append(val_avg_prec)

        scheduler.step(val_loss)

        if  val_avg_prec > best_val_avg_prec:
            best_val_avg_prec = val_avg_prec
            best_model_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            print(f"  --> Epoch {epoch+1}: Best Average Precision Updated: {val_avg_prec:.4f}")

        print(f"Epoch {epoch+1} Train_loss: {train_loss:.4f} | Val_Loss: {val_loss:.4f} | Val_AUC: {val_auc:.4f}| Val_avg_prec: {val_avg_prec:.4f}")

    # OOF Predictions
    print(f"Generating OOF predictions for Fold {fold+1}...")
    model.load_state_dict(best_model_state)
    model.eval()

    fold_preds = []
    with torch.no_grad():
        for img, _ in val_loader:
            logits = model(img.to(device))
            probs = torch.sigmoid(logits)
            fold_preds.append(probs.cpu().numpy())

    # Store predictions in the indices corresponding to this validation fold
    oof_probs[val_idx] = np.concatenate(fold_preds, axis=0)

    model_path = f"Models/Climate_data/Best_model_fold_{fold}.pth"
    torch.save(best_model_state, model_path)
    print(f"Saved best model for Fold {fold} to {model_path}")

    plt.figure(figsize=(8,5))
    plt.plot(train_loss_list, label='Training Loss', color='blue', marker='o')
    plt.plot(val_loss_list, label='Validation Loss', color='red', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    image_path = f"Models/Climate_data/Fold_{fold}_loss.png"
    plt.savefig(image_path, dpi=300)
    plt.show()

    plt.figure(figsize=(8,5))
    plt.plot(macro_auc_list, label='ROC AUC Score', color='red', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('ROC AUC Score')
    plt.title('Macro ROC AUC Score')
    plt.legend()
    plt.grid(True)
    image_path_ROC_AUC = f"Models/Climate_data/Fold_{fold}_ROC_AUC.png"
    plt.savefig(image_path_ROC_AUC, dpi=300)
    plt.show()

    plt.figure(figsize=(8,5))
    plt.plot(macro_avg_prec_list, label='Average Precision Score', color='red', marker='o')
    plt.xlabel('Epoch')
    plt.ylabel('Average Precision Score')
    plt.title('Macro Average Precision Score')
    plt.legend()
    plt.grid(True)
    Image_path_avg_prec = f"Models/Climate_data/Fold_{fold}_avg_prec.png"
    plt.savefig(Image_path_avg_prec, dpi=300)
    plt.show()


print("Cross-Validation complete.")
# Out:
# --- Starting Fold 1/5 ---
#   --> Epoch 1: Best Average Precision Updated: 0.1092
# Epoch 1 Train_loss: 0.0178 | Val_Loss: 0.0132 | Val_AUC: 0.7150| Val_avg_prec: 0.1092
#   --> Epoch 2: Best Average Precision Updated: 0.1217
# Epoch 2 Train_loss: 0.0134 | Val_Loss: 0.0128 | Val_AUC: 0.7395| Val_avg_prec: 0.1217
#   --> Epoch 3: Best Average Precision Updated: 0.1342
# Epoch 3 Train_loss: 0.0131 | Val_Loss: 0.0127 | Val_AUC: 0.7585| Val_avg_prec: 0.1342
#   --> Epoch 4: Best Average Precision Updated: 0.1378
# Epoch 4 Train_loss: 0.0130 | Val_Loss: 0.0126 | Val_AUC: 0.7625| Val_avg_prec: 0.1378
#   --> Epoch 5: Best Average Precision Updated: 0.1456
# Epoch 5 Train_loss: 0.0129 | Val_Loss: 0.0125 | Val_AUC: 0.7699| Val_avg_prec: 0.1456
# Epoch 6 Train_loss: 0.0128 | Val_Loss: 0.0130 | Val_AUC: 0.7500| Val_avg_prec: 0.1333
# Epoch 7 Train_loss: 0.0128 | Val_Loss: 0.0126 | Val_AUC: 0.7678| Val_avg_prec: 0.1419
# Epoch 8 Train_loss: 0.0128 | Val_Loss: 0.0126 | Val_AUC: 0.7677| Val_avg_prec: 0.1439
#   --> Epoch 9: Best Average Precision Updated: 0.1458
# Epoch 9 Train_loss: 0.0127 | Val_Loss: 0.0125 | Val_AUC: 0.7720| Val_avg_prec: 0.1458
# Epoch 10 Train_loss: 0.0126 | Val_Loss: 0.0127 | Val_AUC: 0.7580| Val_avg_prec: 0.1436
# Epoch 11 Train_loss: 0.0126 | Val_Loss: 0.0130 | Val_AUC: 0.7508| Val_avg_prec: 0.1423
#   --> Epoch 12: Best Average Precision Updated: 0.1500
# Epoch 12 Train_loss: 0.0126 | Val_Loss: 0.0123 | Val_AUC: 0.7752| Val_avg_prec: 0.1500
#   --> Epoch 13: Best Average Precision Updated: 0.1524
# Epoch 13 Train_loss: 0.0125 | Val_Loss: 0.0124 | Val_AUC: 0.7743| Val_avg_prec: 0.1524
# Epoch 14 Train_loss: 0.0125 | Val_Loss: 0.0124 | Val_AUC: 0.7755| Val_avg_prec: 0.1517
# Epoch 15 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7769| Val_avg_prec: 0.1516
# Epoch 16 Train_loss: 0.0124 | Val_Loss: 0.0125 | Val_AUC: 0.7679| Val_avg_prec: 0.1445
# Epoch 17 Train_loss: 0.0124 | Val_Loss: 0.0125 | Val_AUC: 0.7699| Val_avg_prec: 0.1496
#   --> Epoch 18: Best Average Precision Updated: 0.1575
# Epoch 18 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7809| Val_avg_prec: 0.1575
# Epoch 19 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7817| Val_avg_prec: 0.1569
#   --> Epoch 20: Best Average Precision Updated: 0.1621
# Epoch 20 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7749| Val_avg_prec: 0.1621
# Epoch 21 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7770| Val_avg_prec: 0.1528
# Epoch 22 Train_loss: 0.0122 | Val_Loss: 0.0128 | Val_AUC: 0.7583| Val_avg_prec: 0.1442
# Epoch 23 Train_loss: 0.0122 | Val_Loss: 0.0125 | Val_AUC: 0.7759| Val_avg_prec: 0.1500
# Epoch 24 Train_loss: 0.0122 | Val_Loss: 0.0122 | Val_AUC: 0.7857| Val_avg_prec: 0.1619
# Epoch 25 Train_loss: 0.0122 | Val_Loss: 0.0125 | Val_AUC: 0.7750| Val_avg_prec: 0.1506
# Epoch 26 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7822| Val_avg_prec: 0.1556
# Epoch 27 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7813| Val_avg_prec: 0.1566
# Epoch 28 Train_loss: 0.0121 | Val_Loss: 0.0126 | Val_AUC: 0.7696| Val_avg_prec: 0.1485
#   --> Epoch 29: Best Average Precision Updated: 0.1622
# Epoch 29 Train_loss: 0.0121 | Val_Loss: 0.0122 | Val_AUC: 0.7857| Val_avg_prec: 0.1622
# Epoch 30 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7720| Val_avg_prec: 0.1522
# Epoch 31 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7747| Val_avg_prec: 0.1552
# Epoch 32 Train_loss: 0.0121 | Val_Loss: 0.0122 | Val_AUC: 0.7814| Val_avg_prec: 0.1557
#   --> Epoch 33: Best Average Precision Updated: 0.1648
# Epoch 33 Train_loss: 0.0121 | Val_Loss: 0.0121 | Val_AUC: 0.7862| Val_avg_prec: 0.1648
# Epoch 34 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7766| Val_avg_prec: 0.1554
# Epoch 35 Train_loss: 0.0120 | Val_Loss: 0.0123 | Val_AUC: 0.7777| Val_avg_prec: 0.1549
# Epoch 36 Train_loss: 0.0120 | Val_Loss: 0.0123 | Val_AUC: 0.7855| Val_avg_prec: 0.1634
#   --> Epoch 37: Best Average Precision Updated: 0.1656
# Epoch 37 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7858| Val_avg_prec: 0.1656
#   --> Epoch 38: Best Average Precision Updated: 0.1679
# Epoch 38 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7879| Val_avg_prec: 0.1679
# Epoch 39 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7898| Val_avg_prec: 0.1667
# Epoch 40 Train_loss: 0.0119 | Val_Loss: 0.0125 | Val_AUC: 0.7673| Val_avg_prec: 0.1528
# Epoch 41 Train_loss: 0.0119 | Val_Loss: 0.0123 | Val_AUC: 0.7809| Val_avg_prec: 0.1583
# Epoch 42 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7897| Val_avg_prec: 0.1624
# Epoch 43 Train_loss: 0.0119 | Val_Loss: 0.0122 | Val_AUC: 0.7895| Val_avg_prec: 0.1641
# Epoch 44 Train_loss: 0.0119 | Val_Loss: 0.0122 | Val_AUC: 0.7878| Val_avg_prec: 0.1626
# Epoch 45 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7890| Val_avg_prec: 0.1626
# Epoch 46 Train_loss: 0.0119 | Val_Loss: 0.0122 | Val_AUC: 0.7861| Val_avg_prec: 0.1670
#   --> Epoch 47: Best Average Precision Updated: 0.1731
# Epoch 47 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7883| Val_avg_prec: 0.1731
# Epoch 48 Train_loss: 0.0119 | Val_Loss: 0.0124 | Val_AUC: 0.7640| Val_avg_prec: 0.1521
# Epoch 49 Train_loss: 0.0118 | Val_Loss: 0.0122 | Val_AUC: 0.7853| Val_avg_prec: 0.1661
#   --> Epoch 50: Best Average Precision Updated: 0.1735
# Epoch 50 Train_loss: 0.0118 | Val_Loss: 0.0120 | Val_AUC: 0.7933| Val_avg_prec: 0.1735
# Generating OOF predictions for Fold 1...
# Saved best model for Fold 0 to Models/Climate_data/Best_model_fold_0.pth
# --- Starting Fold 2/5 ---
#   --> Epoch 1: Best Average Precision Updated: 0.1115
# Epoch 1 Train_loss: 0.0179 | Val_Loss: 0.0132 | Val_AUC: 0.7206| Val_avg_prec: 0.1115
#   --> Epoch 2: Best Average Precision Updated: 0.1275
# Epoch 2 Train_loss: 0.0133 | Val_Loss: 0.0130 | Val_AUC: 0.7464| Val_avg_prec: 0.1275
# Epoch 3 Train_loss: 0.0130 | Val_Loss: 0.0137 | Val_AUC: 0.7360| Val_avg_prec: 0.1230
#   --> Epoch 4: Best Average Precision Updated: 0.1315
# Epoch 4 Train_loss: 0.0129 | Val_Loss: 0.0130 | Val_AUC: 0.7523| Val_avg_prec: 0.1315
#   --> Epoch 5: Best Average Precision Updated: 0.1429
# Epoch 5 Train_loss: 0.0129 | Val_Loss: 0.0127 | Val_AUC: 0.7670| Val_avg_prec: 0.1429
#   --> Epoch 6: Best Average Precision Updated: 0.1487
# Epoch 6 Train_loss: 0.0128 | Val_Loss: 0.0127 | Val_AUC: 0.7756| Val_avg_prec: 0.1487
# Epoch 7 Train_loss: 0.0128 | Val_Loss: 0.0127 | Val_AUC: 0.7633| Val_avg_prec: 0.1429
# Epoch 8 Train_loss: 0.0127 | Val_Loss: 0.0127 | Val_AUC: 0.7616| Val_avg_prec: 0.1409
# Epoch 9 Train_loss: 0.0126 | Val_Loss: 0.0128 | Val_AUC: 0.7695| Val_avg_prec: 0.1418
#   --> Epoch 10: Best Average Precision Updated: 0.1561
# Epoch 10 Train_loss: 0.0126 | Val_Loss: 0.0125 | Val_AUC: 0.7817| Val_avg_prec: 0.1561
# Epoch 11 Train_loss: 0.0126 | Val_Loss: 0.0125 | Val_AUC: 0.7801| Val_avg_prec: 0.1524
#   --> Epoch 12: Best Average Precision Updated: 0.1579
# Epoch 12 Train_loss: 0.0125 | Val_Loss: 0.0125 | Val_AUC: 0.7791| Val_avg_prec: 0.1579
# Epoch 13 Train_loss: 0.0125 | Val_Loss: 0.0125 | Val_AUC: 0.7863| Val_avg_prec: 0.1549
# Epoch 14 Train_loss: 0.0125 | Val_Loss: 0.0126 | Val_AUC: 0.7674| Val_avg_prec: 0.1465
# Epoch 15 Train_loss: 0.0124 | Val_Loss: 0.0127 | Val_AUC: 0.7698| Val_avg_prec: 0.1475
# Epoch 16 Train_loss: 0.0124 | Val_Loss: 0.0128 | Val_AUC: 0.7677| Val_avg_prec: 0.1507
#   --> Epoch 17: Best Average Precision Updated: 0.1582
# Epoch 17 Train_loss: 0.0124 | Val_Loss: 0.0125 | Val_AUC: 0.7855| Val_avg_prec: 0.1582
#   --> Epoch 18: Best Average Precision Updated: 0.1640
# Epoch 18 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7887| Val_avg_prec: 0.1640
# Epoch 19 Train_loss: 0.0123 | Val_Loss: 0.0126 | Val_AUC: 0.7804| Val_avg_prec: 0.1577
# Epoch 20 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7896| Val_avg_prec: 0.1574
# Epoch 21 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7869| Val_avg_prec: 0.1548
#   --> Epoch 22: Best Average Precision Updated: 0.1699
# Epoch 22 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7956| Val_avg_prec: 0.1699
# Epoch 23 Train_loss: 0.0122 | Val_Loss: 0.0124 | Val_AUC: 0.7900| Val_avg_prec: 0.1660
# Epoch 24 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7877| Val_avg_prec: 0.1613
#   --> Epoch 25: Best Average Precision Updated: 0.1709
# Epoch 25 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7925| Val_avg_prec: 0.1709
# Epoch 26 Train_loss: 0.0122 | Val_Loss: 0.0122 | Val_AUC: 0.7961| Val_avg_prec: 0.1698
# Epoch 27 Train_loss: 0.0121 | Val_Loss: 0.0123 | Val_AUC: 0.7892| Val_avg_prec: 0.1641
# Epoch 28 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7948| Val_avg_prec: 0.1657
#   --> Epoch 29: Best Average Precision Updated: 0.1741
# Epoch 29 Train_loss: 0.0121 | Val_Loss: 0.0122 | Val_AUC: 0.7963| Val_avg_prec: 0.1741
# Epoch 30 Train_loss: 0.0121 | Val_Loss: 0.0123 | Val_AUC: 0.7893| Val_avg_prec: 0.1666
# Epoch 31 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7890| Val_avg_prec: 0.1697
# Epoch 32 Train_loss: 0.0120 | Val_Loss: 0.0135 | Val_AUC: 0.7500| Val_avg_prec: 0.1421
#   --> Epoch 33: Best Average Precision Updated: 0.1741
# Epoch 33 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7981| Val_avg_prec: 0.1741
# Epoch 34 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7976| Val_avg_prec: 0.1731
#   --> Epoch 35: Best Average Precision Updated: 0.1798
# Epoch 35 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.8006| Val_avg_prec: 0.1798
# Epoch 36 Train_loss: 0.0120 | Val_Loss: 0.0124 | Val_AUC: 0.7824| Val_avg_prec: 0.1593
# Epoch 37 Train_loss: 0.0119 | Val_Loss: 0.0125 | Val_AUC: 0.7787| Val_avg_prec: 0.1651
# Epoch 38 Train_loss: 0.0120 | Val_Loss: 0.0123 | Val_AUC: 0.7933| Val_avg_prec: 0.1724
# Epoch 39 Train_loss: 0.0119 | Val_Loss: 0.0123 | Val_AUC: 0.7947| Val_avg_prec: 0.1714
# Epoch 40 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7995| Val_avg_prec: 0.1718
# Epoch 41 Train_loss: 0.0119 | Val_Loss: 0.0123 | Val_AUC: 0.7920| Val_avg_prec: 0.1696
#   --> Epoch 42: Best Average Precision Updated: 0.1854
# Epoch 42 Train_loss: 0.0117 | Val_Loss: 0.0120 | Val_AUC: 0.8070| Val_avg_prec: 0.1854
#   --> Epoch 43: Best Average Precision Updated: 0.1871
# Epoch 43 Train_loss: 0.0117 | Val_Loss: 0.0120 | Val_AUC: 0.8074| Val_avg_prec: 0.1871
# Epoch 44 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8072| Val_avg_prec: 0.1863
# Epoch 45 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8079| Val_avg_prec: 0.1863
#   --> Epoch 46: Best Average Precision Updated: 0.1877
# Epoch 46 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8101| Val_avg_prec: 0.1877
#   --> Epoch 47: Best Average Precision Updated: 0.1881
# Epoch 47 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8083| Val_avg_prec: 0.1881
#   --> Epoch 48: Best Average Precision Updated: 0.1890
# Epoch 48 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8093| Val_avg_prec: 0.1890
#   --> Epoch 49: Best Average Precision Updated: 0.1890
# Epoch 49 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8098| Val_avg_prec: 0.1890
# Epoch 50 Train_loss: 0.0116 | Val_Loss: 0.0119 | Val_AUC: 0.8094| Val_avg_prec: 0.1888
# Generating OOF predictions for Fold 2...
# Saved best model for Fold 1 to Models/Climate_data/Best_model_fold_1.pth
# --- Starting Fold 3/5 ---
#   --> Epoch 1: Best Average Precision Updated: 0.1076
# Epoch 1 Train_loss: 0.0182 | Val_Loss: 0.0132 | Val_AUC: 0.7137| Val_avg_prec: 0.1076
#   --> Epoch 2: Best Average Precision Updated: 0.1190
# Epoch 2 Train_loss: 0.0133 | Val_Loss: 0.0128 | Val_AUC: 0.7377| Val_avg_prec: 0.1190
#   --> Epoch 3: Best Average Precision Updated: 0.1306
# Epoch 3 Train_loss: 0.0130 | Val_Loss: 0.0127 | Val_AUC: 0.7587| Val_avg_prec: 0.1306
# Epoch 4 Train_loss: 0.0130 | Val_Loss: 0.0132 | Val_AUC: 0.7495| Val_avg_prec: 0.1300
#   --> Epoch 5: Best Average Precision Updated: 0.1419
# Epoch 5 Train_loss: 0.0129 | Val_Loss: 0.0125 | Val_AUC: 0.7714| Val_avg_prec: 0.1419
#   --> Epoch 6: Best Average Precision Updated: 0.1424
# Epoch 6 Train_loss: 0.0128 | Val_Loss: 0.0127 | Val_AUC: 0.7630| Val_avg_prec: 0.1424
#   --> Epoch 7: Best Average Precision Updated: 0.1481
# Epoch 7 Train_loss: 0.0128 | Val_Loss: 0.0124 | Val_AUC: 0.7739| Val_avg_prec: 0.1481
# Epoch 8 Train_loss: 0.0127 | Val_Loss: 0.0124 | Val_AUC: 0.7733| Val_avg_prec: 0.1450
# Epoch 9 Train_loss: 0.0126 | Val_Loss: 0.0125 | Val_AUC: 0.7676| Val_avg_prec: 0.1406
# Epoch 10 Train_loss: 0.0126 | Val_Loss: 0.0126 | Val_AUC: 0.7673| Val_avg_prec: 0.1478
#   --> Epoch 11: Best Average Precision Updated: 0.1509
# Epoch 11 Train_loss: 0.0126 | Val_Loss: 0.0125 | Val_AUC: 0.7713| Val_avg_prec: 0.1509
# Epoch 12 Train_loss: 0.0125 | Val_Loss: 0.0127 | Val_AUC: 0.7593| Val_avg_prec: 0.1445
#   --> Epoch 13: Best Average Precision Updated: 0.1617
# Epoch 13 Train_loss: 0.0125 | Val_Loss: 0.0122 | Val_AUC: 0.7866| Val_avg_prec: 0.1617
# Epoch 14 Train_loss: 0.0125 | Val_Loss: 0.0124 | Val_AUC: 0.7810| Val_avg_prec: 0.1591
# Epoch 15 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7847| Val_avg_prec: 0.1534
# Epoch 16 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7851| Val_avg_prec: 0.1565
# Epoch 17 Train_loss: 0.0124 | Val_Loss: 0.0123 | Val_AUC: 0.7797| Val_avg_prec: 0.1594
#   --> Epoch 18: Best Average Precision Updated: 0.1727
# Epoch 18 Train_loss: 0.0124 | Val_Loss: 0.0122 | Val_AUC: 0.7858| Val_avg_prec: 0.1727
# Epoch 19 Train_loss: 0.0123 | Val_Loss: 0.0123 | Val_AUC: 0.7891| Val_avg_prec: 0.1619
# Epoch 20 Train_loss: 0.0123 | Val_Loss: 0.0124 | Val_AUC: 0.7826| Val_avg_prec: 0.1597
# Epoch 21 Train_loss: 0.0123 | Val_Loss: 0.0121 | Val_AUC: 0.7894| Val_avg_prec: 0.1678
#   --> Epoch 22: Best Average Precision Updated: 0.1735
# Epoch 22 Train_loss: 0.0123 | Val_Loss: 0.0121 | Val_AUC: 0.7914| Val_avg_prec: 0.1735
# Epoch 23 Train_loss: 0.0122 | Val_Loss: 0.0122 | Val_AUC: 0.7877| Val_avg_prec: 0.1603
# Epoch 24 Train_loss: 0.0123 | Val_Loss: 0.0122 | Val_AUC: 0.7831| Val_avg_prec: 0.1630
# Epoch 25 Train_loss: 0.0122 | Val_Loss: 0.0123 | Val_AUC: 0.7824| Val_avg_prec: 0.1689
# Epoch 26 Train_loss: 0.0122 | Val_Loss: 0.0125 | Val_AUC: 0.7697| Val_avg_prec: 0.1531
# Epoch 27 Train_loss: 0.0122 | Val_Loss: 0.0125 | Val_AUC: 0.7745| Val_avg_prec: 0.1557
# Epoch 28 Train_loss: 0.0121 | Val_Loss: 0.0121 | Val_AUC: 0.7902| Val_avg_prec: 0.1709
#   --> Epoch 29: Best Average Precision Updated: 0.1746
# Epoch 29 Train_loss: 0.0122 | Val_Loss: 0.0121 | Val_AUC: 0.7896| Val_avg_prec: 0.1746
# Epoch 30 Train_loss: 0.0121 | Val_Loss: 0.0121 | Val_AUC: 0.7930| Val_avg_prec: 0.1699
# Epoch 31 Train_loss: 0.0121 | Val_Loss: 0.0121 | Val_AUC: 0.7906| Val_avg_prec: 0.1655
# Epoch 32 Train_loss: 0.0121 | Val_Loss: 0.0122 | Val_AUC: 0.7852| Val_avg_prec: 0.1717
# Epoch 33 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7911| Val_avg_prec: 0.1660
# Epoch 34 Train_loss: 0.0121 | Val_Loss: 0.0123 | Val_AUC: 0.7756| Val_avg_prec: 0.1604
#   --> Epoch 35: Best Average Precision Updated: 0.1851
# Epoch 35 Train_loss: 0.0118 | Val_Loss: 0.0118 | Val_AUC: 0.8030| Val_avg_prec: 0.1851
#   --> Epoch 36: Best Average Precision Updated: 0.1872
# Epoch 36 Train_loss: 0.0118 | Val_Loss: 0.0118 | Val_AUC: 0.8051| Val_avg_prec: 0.1872
#   --> Epoch 37: Best Average Precision Updated: 0.1875
# Epoch 37 Train_loss: 0.0118 | Val_Loss: 0.0118 | Val_AUC: 0.8048| Val_avg_prec: 0.1875
# Epoch 38 Train_loss: 0.0118 | Val_Loss: 0.0118 | Val_AUC: 0.8043| Val_avg_prec: 0.1853
# Epoch 39 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8043| Val_avg_prec: 0.1849
# Epoch 40 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8053| Val_avg_prec: 0.1869
# Epoch 41 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8060| Val_avg_prec: 0.1872
#   --> Epoch 42: Best Average Precision Updated: 0.1888
# Epoch 42 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8065| Val_avg_prec: 0.1888
# Epoch 43 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8055| Val_avg_prec: 0.1880
# Epoch 44 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8059| Val_avg_prec: 0.1875
# Epoch 45 Train_loss: 0.0118 | Val_Loss: 0.0118 | Val_AUC: 0.8055| Val_avg_prec: 0.1850
# Epoch 46 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8052| Val_avg_prec: 0.1878
# Epoch 47 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8062| Val_avg_prec: 0.1883
# Epoch 48 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8068| Val_avg_prec: 0.1879
# Epoch 49 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8070| Val_avg_prec: 0.1881
# Epoch 50 Train_loss: 0.0117 | Val_Loss: 0.0118 | Val_AUC: 0.8064| Val_avg_prec: 0.1884
# Generating OOF predictions for Fold 3...
# Saved best model for Fold 2 to Models/Climate_data/Best_model_fold_2.pth
# --- Starting Fold 4/5 ---
#   --> Epoch 1: Best Average Precision Updated: 0.1031
# Epoch 1 Train_loss: 0.0180 | Val_Loss: 0.0139 | Val_AUC: 0.6872| Val_avg_prec: 0.1031
#   --> Epoch 2: Best Average Precision Updated: 0.1336
# Epoch 2 Train_loss: 0.0133 | Val_Loss: 0.0129 | Val_AUC: 0.7542| Val_avg_prec: 0.1336
#   --> Epoch 3: Best Average Precision Updated: 0.1389
# Epoch 3 Train_loss: 0.0131 | Val_Loss: 0.0128 | Val_AUC: 0.7609| Val_avg_prec: 0.1389
#   --> Epoch 4: Best Average Precision Updated: 0.1452
# Epoch 4 Train_loss: 0.0130 | Val_Loss: 0.0127 | Val_AUC: 0.7672| Val_avg_prec: 0.1452
# Epoch 5 Train_loss: 0.0129 | Val_Loss: 0.0131 | Val_AUC: 0.7528| Val_avg_prec: 0.1363
# Epoch 6 Train_loss: 0.0128 | Val_Loss: 0.0137 | Val_AUC: 0.7364| Val_avg_prec: 0.1294
#   --> Epoch 7: Best Average Precision Updated: 0.1499
# Epoch 7 Train_loss: 0.0127 | Val_Loss: 0.0129 | Val_AUC: 0.7713| Val_avg_prec: 0.1499
# Epoch 8 Train_loss: 0.0127 | Val_Loss: 0.0129 | Val_AUC: 0.7595| Val_avg_prec: 0.1439
#   --> Epoch 9: Best Average Precision Updated: 0.1525
# Epoch 9 Train_loss: 0.0126 | Val_Loss: 0.0127 | Val_AUC: 0.7762| Val_avg_prec: 0.1525
# Epoch 10 Train_loss: 0.0126 | Val_Loss: 0.0133 | Val_AUC: 0.7492| Val_avg_prec: 0.1414
#   --> Epoch 11: Best Average Precision Updated: 0.1531
# Epoch 11 Train_loss: 0.0126 | Val_Loss: 0.0126 | Val_AUC: 0.7765| Val_avg_prec: 0.1531
# Epoch 12 Train_loss: 0.0125 | Val_Loss: 0.0130 | Val_AUC: 0.7670| Val_avg_prec: 0.1428
# Epoch 13 Train_loss: 0.0125 | Val_Loss: 0.0126 | Val_AUC: 0.7762| Val_avg_prec: 0.1504
#   --> Epoch 14: Best Average Precision Updated: 0.1602
# Epoch 14 Train_loss: 0.0124 | Val_Loss: 0.0125 | Val_AUC: 0.7800| Val_avg_prec: 0.1602
# Epoch 15 Train_loss: 0.0124 | Val_Loss: 0.0126 | Val_AUC: 0.7810| Val_avg_prec: 0.1572
# Epoch 16 Train_loss: 0.0123 | Val_Loss: 0.0125 | Val_AUC: 0.7827| Val_avg_prec: 0.1597
#   --> Epoch 17: Best Average Precision Updated: 0.1645
# Epoch 17 Train_loss: 0.0123 | Val_Loss: 0.0125 | Val_AUC: 0.7843| Val_avg_prec: 0.1645
#   --> Epoch 18: Best Average Precision Updated: 0.1653
# Epoch 18 Train_loss: 0.0123 | Val_Loss: 0.0125 | Val_AUC: 0.7848| Val_avg_prec: 0.1653
# Epoch 19 Train_loss: 0.0123 | Val_Loss: 0.0126 | Val_AUC: 0.7775| Val_avg_prec: 0.1618
# Epoch 20 Train_loss: 0.0122 | Val_Loss: 0.0127 | Val_AUC: 0.7693| Val_avg_prec: 0.1508
# Epoch 21 Train_loss: 0.0123 | Val_Loss: 0.0126 | Val_AUC: 0.7784| Val_avg_prec: 0.1638
# Epoch 22 Train_loss: 0.0122 | Val_Loss: 0.0126 | Val_AUC: 0.7766| Val_avg_prec: 0.1569
# Epoch 23 Train_loss: 0.0122 | Val_Loss: 0.0126 | Val_AUC: 0.7762| Val_avg_prec: 0.1562
#   --> Epoch 24: Best Average Precision Updated: 0.1717
# Epoch 24 Train_loss: 0.0122 | Val_Loss: 0.0124 | Val_AUC: 0.7886| Val_avg_prec: 0.1717
# Epoch 25 Train_loss: 0.0122 | Val_Loss: 0.0125 | Val_AUC: 0.7799| Val_avg_prec: 0.1630
# Epoch 26 Train_loss: 0.0121 | Val_Loss: 0.0125 | Val_AUC: 0.7860| Val_avg_prec: 0.1644
# Epoch 27 Train_loss: 0.0121 | Val_Loss: 0.0125 | Val_AUC: 0.7814| Val_avg_prec: 0.1681
# Epoch 28 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7890| Val_avg_prec: 0.1662
# Epoch 29 Train_loss: 0.0121 | Val_Loss: 0.0125 | Val_AUC: 0.7824| Val_avg_prec: 0.1663
#   --> Epoch 30: Best Average Precision Updated: 0.1773
# Epoch 30 Train_loss: 0.0121 | Val_Loss: 0.0124 | Val_AUC: 0.7912| Val_avg_prec: 0.1773
# Epoch 31 Train_loss: 0.0121 | Val_Loss: 0.0125 | Val_AUC: 0.7829| Val_avg_prec: 0.1640
# Epoch 32 Train_loss: 0.0120 | Val_Loss: 0.0126 | Val_AUC: 0.7741| Val_avg_prec: 0.1589
# Epoch 33 Train_loss: 0.0120 | Val_Loss: 0.0123 | Val_AUC: 0.7914| Val_avg_prec: 0.1765
# Epoch 34 Train_loss: 0.0120 | Val_Loss: 0.0125 | Val_AUC: 0.7815| Val_avg_prec: 0.1700
# Epoch 35 Train_loss: 0.0120 | Val_Loss: 0.0130 | Val_AUC: 0.7609| Val_avg_prec: 0.1544
# Epoch 36 Train_loss: 0.0120 | Val_Loss: 0.0124 | Val_AUC: 0.7903| Val_avg_prec: 0.1745
# Epoch 37 Train_loss: 0.0120 | Val_Loss: 0.0128 | Val_AUC: 0.7614| Val_avg_prec: 0.1503
# Epoch 38 Train_loss: 0.0119 | Val_Loss: 0.0124 | Val_AUC: 0.7849| Val_avg_prec: 0.1705
#   --> Epoch 39: Best Average Precision Updated: 0.1786
# Epoch 39 Train_loss: 0.0119 | Val_Loss: 0.0123 | Val_AUC: 0.7907| Val_avg_prec: 0.1786
#   --> Epoch 40: Best Average Precision Updated: 0.1888
# Epoch 40 Train_loss: 0.0117 | Val_Loss: 0.0120 | Val_AUC: 0.8030| Val_avg_prec: 0.1888
#   --> Epoch 41: Best Average Precision Updated: 0.1910
# Epoch 41 Train_loss: 0.0117 | Val_Loss: 0.0120 | Val_AUC: 0.8041| Val_avg_prec: 0.1910
# Epoch 42 Train_loss: 0.0117 | Val_Loss: 0.0120 | Val_AUC: 0.8023| Val_avg_prec: 0.1891
#   --> Epoch 43: Best Average Precision Updated: 0.1912
# Epoch 43 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8052| Val_avg_prec: 0.1912
#   --> Epoch 44: Best Average Precision Updated: 0.1921
# Epoch 44 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8051| Val_avg_prec: 0.1921
# Epoch 45 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8052| Val_avg_prec: 0.1910
#   --> Epoch 46: Best Average Precision Updated: 0.1928
# Epoch 46 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8059| Val_avg_prec: 0.1928
# Epoch 47 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8033| Val_avg_prec: 0.1919
#   --> Epoch 48: Best Average Precision Updated: 0.1939
# Epoch 48 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8054| Val_avg_prec: 0.1939
# Epoch 49 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8064| Val_avg_prec: 0.1918
# Epoch 50 Train_loss: 0.0116 | Val_Loss: 0.0120 | Val_AUC: 0.8068| Val_avg_prec: 0.1926
# Generating OOF predictions for Fold 4...
# Saved best model for Fold 3 to Models/Climate_data/Best_model_fold_3.pth
# --- Starting Fold 5/5 ---
#   --> Epoch 1: Best Average Precision Updated: 0.1068
# Epoch 1 Train_loss: 0.0181 | Val_Loss: 0.0135 | Val_AUC: 0.7096| Val_avg_prec: 0.1068
#   --> Epoch 2: Best Average Precision Updated: 0.1255
# Epoch 2 Train_loss: 0.0134 | Val_Loss: 0.0130 | Val_AUC: 0.7474| Val_avg_prec: 0.1255
#   --> Epoch 3: Best Average Precision Updated: 0.1305
# Epoch 3 Train_loss: 0.0132 | Val_Loss: 0.0129 | Val_AUC: 0.7570| Val_avg_prec: 0.1305
# Epoch 4 Train_loss: 0.0130 | Val_Loss: 0.0131 | Val_AUC: 0.7524| Val_avg_prec: 0.1296
#   --> Epoch 5: Best Average Precision Updated: 0.1377
# Epoch 5 Train_loss: 0.0129 | Val_Loss: 0.0128 | Val_AUC: 0.7628| Val_avg_prec: 0.1377
#   --> Epoch 6: Best Average Precision Updated: 0.1406
# Epoch 6 Train_loss: 0.0128 | Val_Loss: 0.0127 | Val_AUC: 0.7656| Val_avg_prec: 0.1406
#   --> Epoch 7: Best Average Precision Updated: 0.1485
# Epoch 7 Train_loss: 0.0127 | Val_Loss: 0.0126 | Val_AUC: 0.7728| Val_avg_prec: 0.1485
# Epoch 8 Train_loss: 0.0127 | Val_Loss: 0.0126 | Val_AUC: 0.7765| Val_avg_prec: 0.1440
# Epoch 9 Train_loss: 0.0127 | Val_Loss: 0.0126 | Val_AUC: 0.7756| Val_avg_prec: 0.1440
# Epoch 10 Train_loss: 0.0126 | Val_Loss: 0.0128 | Val_AUC: 0.7664| Val_avg_prec: 0.1401
#   --> Epoch 11: Best Average Precision Updated: 0.1555
# Epoch 11 Train_loss: 0.0125 | Val_Loss: 0.0125 | Val_AUC: 0.7787| Val_avg_prec: 0.1555
# Epoch 12 Train_loss: 0.0126 | Val_Loss: 0.0126 | Val_AUC: 0.7752| Val_avg_prec: 0.1519
# Epoch 13 Train_loss: 0.0125 | Val_Loss: 0.0127 | Val_AUC: 0.7697| Val_avg_prec: 0.1481
#   --> Epoch 14: Best Average Precision Updated: 0.1559
# Epoch 14 Train_loss: 0.0125 | Val_Loss: 0.0126 | Val_AUC: 0.7735| Val_avg_prec: 0.1559
# Epoch 15 Train_loss: 0.0124 | Val_Loss: 0.0127 | Val_AUC: 0.7732| Val_avg_prec: 0.1536
# Epoch 16 Train_loss: 0.0124 | Val_Loss: 0.0128 | Val_AUC: 0.7678| Val_avg_prec: 0.1549
# Epoch 17 Train_loss: 0.0124 | Val_Loss: 0.0130 | Val_AUC: 0.7586| Val_avg_prec: 0.1458
#   --> Epoch 18: Best Average Precision Updated: 0.1714
# Epoch 18 Train_loss: 0.0122 | Val_Loss: 0.0121 | Val_AUC: 0.7929| Val_avg_prec: 0.1714
# Epoch 19 Train_loss: 0.0121 | Val_Loss: 0.0121 | Val_AUC: 0.7940| Val_avg_prec: 0.1714
# Epoch 20 Train_loss: 0.0120 | Val_Loss: 0.0122 | Val_AUC: 0.7939| Val_avg_prec: 0.1677
# Epoch 21 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7946| Val_avg_prec: 0.1710
#   --> Epoch 22: Best Average Precision Updated: 0.1722
# Epoch 22 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7954| Val_avg_prec: 0.1722
# Epoch 23 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7948| Val_avg_prec: 0.1710
# Epoch 24 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7957| Val_avg_prec: 0.1715
# Epoch 25 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7948| Val_avg_prec: 0.1717
#   --> Epoch 26: Best Average Precision Updated: 0.1756
# Epoch 26 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7973| Val_avg_prec: 0.1756
#   --> Epoch 27: Best Average Precision Updated: 0.1766
# Epoch 27 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7959| Val_avg_prec: 0.1766
#   --> Epoch 28: Best Average Precision Updated: 0.1789
# Epoch 28 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7983| Val_avg_prec: 0.1789
# Epoch 29 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7986| Val_avg_prec: 0.1758
# Epoch 30 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7978| Val_avg_prec: 0.1736
# Epoch 31 Train_loss: 0.0120 | Val_Loss: 0.0121 | Val_AUC: 0.7970| Val_avg_prec: 0.1749
# Epoch 32 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7968| Val_avg_prec: 0.1733
# Epoch 33 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7970| Val_avg_prec: 0.1750
#   --> Epoch 34: Best Average Precision Updated: 0.1797
# Epoch 34 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7982| Val_avg_prec: 0.1797
# Epoch 35 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7972| Val_avg_prec: 0.1766
# Epoch 36 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7988| Val_avg_prec: 0.1792
# Epoch 37 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7980| Val_avg_prec: 0.1769
# Epoch 38 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7989| Val_avg_prec: 0.1768
# Epoch 39 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7974| Val_avg_prec: 0.1767
# Epoch 40 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7994| Val_avg_prec: 0.1765
# Epoch 41 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.7995| Val_avg_prec: 0.1774
# Epoch 42 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7985| Val_avg_prec: 0.1771
# Epoch 43 Train_loss: 0.0119 | Val_Loss: 0.0121 | Val_AUC: 0.7987| Val_avg_prec: 0.1782
# Epoch 44 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.7997| Val_avg_prec: 0.1786
#   --> Epoch 45: Best Average Precision Updated: 0.1805
# Epoch 45 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.7999| Val_avg_prec: 0.1805
# Epoch 46 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.8001| Val_avg_prec: 0.1784
#   --> Epoch 47: Best Average Precision Updated: 0.1816
# Epoch 47 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.8012| Val_avg_prec: 0.1816
# Epoch 48 Train_loss: 0.0118 | Val_Loss: 0.0120 | Val_AUC: 0.8013| Val_avg_prec: 0.1809
# Epoch 49 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.8006| Val_avg_prec: 0.1784
# Epoch 50 Train_loss: 0.0119 | Val_Loss: 0.0120 | Val_AUC: 0.8003| Val_avg_prec: 0.1809
# Generating OOF predictions for Fold 5...
# Saved best model for Fold 4 to Models/Climate_data/Best_model_fold_4.pth
# Cross-Validation complete.

# %% [markdown]
# ## 5. Test the model

# %%
def ensemble_predictions(model, loader, weight_paths, device="cuda"):
    """
    1. Loads each fold model.
    2. Generates probabilities for the test set.
    3. Averages them (Ensembling).
    """
    model.to(device)
    all_fold_probs = []
    test_labels = []

    for fold_idx, path in enumerate(weight_paths):
        print(f"--> Processing Fold {fold_idx} weights...")

        # Load the saved state dict
        model.load_state_dict(torch.load(path, map_location=device, weights_only=True))
        model.eval()

        fold_probs = []
        with torch.no_grad():
            for img, y in loader:
                img = img.to(device).float()

                # Get logits and convert to probabilities
                logits = model(img)
                probs = torch.sigmoid(logits)

                fold_probs.append(probs.cpu().numpy())

                # Only collect labels once
                if fold_idx == 0:
                    test_labels.append(y.numpy())

        # Combine batches for this specific fold
        all_fold_probs.append(np.concatenate(fold_probs, axis=0))

    # Average probabilities across all folds
    ensemble_probs = np.mean(all_fold_probs, axis=0)

    # Final labels for metric calculation
    labels = np.concatenate(test_labels, axis=0)

    return ensemble_probs, labels

# %%
# List saved model files
fold_weight_files = [f"Models/Climate_data/Best_model_fold_{i}.pth" for i in range(5)]

# Generate the ensemble probabilities
ensemble_probs, test_labels = ensemble_predictions(
    model=TabularEncoder(),
    loader=test_loader,
    weight_paths=fold_weight_files,
    device=device
)
# Out:
# --> Processing Fold 0 weights...
# --> Processing Fold 1 weights...
# --> Processing Fold 2 weights...
# --> Processing Fold 3 weights...
# --> Processing Fold 4 weights...

# %% [markdown]
# ## 6. Evaluate the model

# %% [markdown]
# ### 6.1 Finding best threshold using OOF analysis

# %%
def find_optimal_thresholds(y_true, oof_probs):
    """
    Finds the best threshold for each of the 342 species.
    y_true: Ground truth labels (N, 342)
    oof_probs: Out-of-fold predictions (N, 342)
    """
    num_species = y_true.shape[1]
    best_thresholds = np.zeros(num_species)

    # Range of thresholds to test
    thresholds = np.linspace(0, 1, 100)

    print("Optimizing thresholds for 342 species...")

    for i in range(num_species):
        species_labels = y_true[:, i]
        species_probs = oof_probs[:, i]

        # Default to 0.5
        if species_labels.sum() == 0:
            best_thresholds[i] = 0.5
            continue

        best_fbeta = -1
        best_thresh = 0.5

        for t in thresholds:
            preds = (species_probs >= t).astype(int)
            score = fbeta_score(species_labels, preds, beta=0.5, zero_division=0) # Use fbeta to raise precision

            if score > best_fbeta:
                best_fbeta = score
                best_thresh = t

        best_thresholds[i] = best_thresh

    print("Optimization complete.")
    return best_thresholds

# %%
opt_thresholds = find_optimal_thresholds(species_train, oof_probs)
binary_preds = (ensemble_probs >= opt_thresholds).astype(int)
# Out:
# Optimizing thresholds for 342 species...
# Optimization complete.

# %% [markdown]
# ### 6.2 Fully evaluating the ensemble model

# %%
def full_evaluation(preds, labels, opt_thresholds, binary_preds):
    macro_auc = roc_auc_score(labels, preds, average='macro')
    weighted_auc = roc_auc_score(labels, preds, average='micro')

    macro_avg_prec = average_precision_score(labels, preds, average='macro')
    weighted_avg_prec = average_precision_score(labels, preds, average='micro')

    macro_f1 = f1_score(labels, binary_preds, average='macro')
    weighted_f1 = f1_score(labels, binary_preds, average='micro')

    macro_precision = precision_score(labels, binary_preds, average='macro', zero_division=0)
    weighted_precision = precision_score(labels, binary_preds, average='micro', zero_division=0)

    macro_recall = recall_score(labels, binary_preds, average='macro')
    weighted_recall = recall_score(labels, binary_preds, average='micro')

    subset_acc = (binary_preds == labels).all(axis=1).mean()

    rank_loss = label_ranking_loss(labels, preds)

    return {
        "Macro ROC AUC": macro_auc,
        "Micro ROC AUC": weighted_auc,
        "Macro Average Precision": macro_avg_prec,
        "Micro Average Precision": weighted_avg_prec,
        "Macro Recall": macro_recall,
        "Micro Recall": weighted_recall,
        "Macro F1": macro_f1,
        "Micro F1": weighted_f1,
        "Macro Precision": macro_precision,
        "Micro Precision": weighted_precision,
        "Subset Accuracy": subset_acc,
        "Ranking Loss": rank_loss
    }

# %%
results = full_evaluation(ensemble_probs, test_labels, opt_thresholds, binary_preds)
print("Metrics for focal model:")
for k,v in results.items():
    print(k, ":", v)
# Out:
# Metrics for focal model:
# Macro ROC AUC : 0.8135630902626851
# Micro ROC AUC : 0.8674055858854278
# Macro Average Precision : 0.18600910948073254
# Micro Average Precision : 0.2426045557229175
# Macro Recall : 0.22432528294681545
# Micro Recall : 0.281283919987595
# Macro F1 : 0.18699343674824992
# Micro F1 : 0.24404681824297053
# Macro Precision : 0.23355684853866968
# Micro Precision : 0.21551621717951763
# Subset Accuracy : 0.003
# Ranking Loss : 0.13354267835343864

# %% [markdown]
# # 7. Retraining model on full training dataset using hyperparameters

# %%
full_train_data = GeoPlantDataset(tabular=env_train, labels=species_train, split=None)
full_loader = DataLoader(full_train_data, batch_size=32, shuffle=True)

# Initialize fresh model
final_model = TabularEncoder().to(device)
criterion = MultiLabelFocalLoss(gamma=2.0, alpha=0.25)
optimizer = torch.optim.AdamW(final_model.parameters())

final_epochs = 30

print(f"Starting final retraining on 100% of data for {final_epochs} epochs...")

final_model.train()
for epoch in range(final_epochs):
    train_loss = train_epoch(final_model, full_loader, optimizer, criterion, device=device)
    print(f"Epoch {epoch+1}/{final_epochs} | Loss: {train_loss:.4f}")

torch.save(final_model.state_dict(), "Models/Climate_data/Climate_data_model.pth")
# Out:
# Starting final retraining on 100% of data for 30 epochs...
# Epoch 1/30 | Loss: 0.0173
# Epoch 2/30 | Loss: 0.0133
# Epoch 3/30 | Loss: 0.0130
# Epoch 4/30 | Loss: 0.0129
# Epoch 5/30 | Loss: 0.0128
# Epoch 6/30 | Loss: 0.0128
# Epoch 7/30 | Loss: 0.0127
# Epoch 8/30 | Loss: 0.0126
# Epoch 9/30 | Loss: 0.0126
# Epoch 10/30 | Loss: 0.0126
# Epoch 11/30 | Loss: 0.0125
# Epoch 12/30 | Loss: 0.0125
# Epoch 13/30 | Loss: 0.0124
# Epoch 14/30 | Loss: 0.0124
# Epoch 15/30 | Loss: 0.0124
# Epoch 16/30 | Loss: 0.0123
# Epoch 17/30 | Loss: 0.0123
# Epoch 18/30 | Loss: 0.0123
# Epoch 19/30 | Loss: 0.0123
# Epoch 20/30 | Loss: 0.0122
# Epoch 21/30 | Loss: 0.0122
# Epoch 22/30 | Loss: 0.0122
# Epoch 23/30 | Loss: 0.0122
# Epoch 24/30 | Loss: 0.0122
# Epoch 25/30 | Loss: 0.0121
# Epoch 26/30 | Loss: 0.0121
# Epoch 27/30 | Loss: 0.0121
# Epoch 28/30 | Loss: 0.0121
# Epoch 29/30 | Loss: 0.0121
# Epoch 30/30 | Loss: 0.0121

# %%
def test_merged_model(model, loader, device="cuda"):
    model.eval()
    merged_probs = []
    labels = []

    with torch.no_grad():
        for env, y in loader:

            env = env.to(device).float()

            logits = model(env)
            probs = torch.sigmoid(logits)

            merged_probs.append(probs.cpu())
            labels.append(y)

    merged_probs = torch.cat(merged_probs).numpy()
    labels = torch.cat(labels).numpy()

    return merged_probs, labels

# %%
merged_model_probs, test_labels = test_merged_model(model=final_model, loader=test_loader, device=device)

# %%
merged_model_binary_preds = (merged_model_probs >= opt_thresholds).astype(int)

# %%
results = full_evaluation(merged_model_probs, test_labels, opt_thresholds, merged_model_binary_preds)
print("Metrics for focal model:")
for k,v in results.items():
    print(k, ":", v)
# Out:
# Metrics for focal model:
# Macro ROC AUC : 0.7710414656500632
# Micro ROC AUC : 0.8309215296118878
# Macro Average Precision : 0.15380071113816948
# Micro Average Precision : 0.187529003080843
# Macro Recall : 0.10593519103041411
# Micro Recall : 0.10350441928981237
# Macro F1 : 0.09407834721730757
# Micro F1 : 0.13406979663570173
# Macro Precision : 0.1626457692456352
# Micro Precision : 0.19025224454895254
# Subset Accuracy : 0.002
# Ranking Loss : 0.15964329584889947

# %%
# Calculate F1 per species
from sklearn.metrics import f1_score
per_species_f1 = f1_score(test_labels, merged_model_binary_preds, average=None, zero_division=0)

# Sort them
sorted_indices = np.argsort(per_species_f1)[::-1]

print("Top 5 Species F1:", per_species_f1[sorted_indices[:5]])
print("Bottom 5 Species F1:", per_species_f1[sorted_indices[-5:]])
print("Number of species with 0.0 F1:", np.sum(per_species_f1 == 0))
# Out:
# Top 5 Species F1: [0.72268908 0.64516129 0.60759494 0.57971014 0.50420168]
# Bottom 5 Species F1: [0. 0. 0. 0. 0.]
# Number of species with 0.0 F1: 95

# %% [markdown]
# ### Multilabel confusion matrix

# %%
from sklearn.metrics import multilabel_confusion_matrix

matrices = multilabel_confusion_matrix(test_labels, merged_model_binary_preds)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


first_class_matrix = matrices[9]
first_class_name = "First Class"

# 3. Plot it
plt.figure(figsize=(4, 3))
sns.heatmap(first_class_matrix, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Absent', 'Present'],
            yticklabels=['Absent', 'Present'])

plt.title(f"Confusion Matrix: {first_class_name}")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## 7. Visualization on map

# %%
def map_predictions_species(preds, labels, species_index, test_lats, test_lons, show_types=None):
    """
    Creates a Folium map showing prediction correctness for a specific species.

    Parameters:
    - all_preds: np.array of shape (num_samples, num_species), model predictions (0/1)
    - all_labels: np.array of shape (num_samples, num_species), true labels (0/1)
    - species_index: int, index of the species to visualize
    - test_lats: list or array of latitude values
    - test_lons: list or array of longitude values
    - show_types: set of strings indicating which prediction types to show.
                  Options: 'TP', 'TN', 'FP', 'FN'
                  Default: None (show all)
    """

    print("Number of species prediction:")
    print(preds[:,species_index].sum())
    print("Number of species occurence:")
    print(labels[:,species_index].sum())

    if show_types is None:
        show_types = {'TP', 'TN', 'FP', 'FN'}  # show all by default

    center_lat = np.mean(test_lats)
    center_lon = np.mean(test_lons)
    fmap = folium.Map(location=[center_lat, center_lon], zoom_start=4)

    preds_species = preds[:, species_index]
    labels_species = labels[:, species_index]

    for lat, lon, pred, label in zip(test_lats, test_lons, preds_species, labels_species):
        # Determine prediction type and color
        if pred == 1 and label == 1:
            pred_type = 'TP'
            color = 'green'
        elif pred == 0 and label == 1:
            pred_type = 'FN'
            color = 'red'
        elif pred == 0 and label == 0:
            pred_type = 'TN'
            color = 'blue'
        else:  # pred == 1 and label == 0
            pred_type = 'FP'
            color = 'orange'

        if pred_type not in show_types:
            continue  # skip this point if not in selected types

        folium.CircleMarker(
            location=[lat, lon],
            radius=4,
            color=color,
            fill=True,
            fill_opacity=0.6
        ).add_to(fmap)

    return fmap

# %%
map_predictions_species(preds=binary_preds, labels=test_labels, species_index=30, test_lats=test_lats, test_lons=test_lons)
# Out:
# Number of species prediction:
# 42
# Number of species occurence:
# 46.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3028321508.py in <cell line: 0>()
# ----> 1 map_predictions_species(preds=binary_preds, labels=test_labels, species_index=30, test_lats=test_lats, test_lons=test_lons)
#
# /tmp/ipython-input-814430739.py in map_predictions_species(preds, labels, species_index, test_lats, test_lons, show_types)
#      24     center_lat = np.mean(test_lats)
#      25     center_lon = np.mean(test_lons)
# ---> 26     fmap = folium.Map(location=[center_lat, center_lon], zoom_start=4)
#      27
#      28     preds_species = preds[:, species_index]
#
# NameError: name 'folium' is not defined
